# %%
import sys
from PyQt5.QtWidgets import *
from PyQt5.QtGui import *
import numpy as np
from ball import *

# Ball 클래스
class Ball():
    def __init__(self, x, y, w, h, c, speedx, speedy):
        super().__init__()

        self.x = x
        self.y = y
        self.w = w
        self.h = h
        self.c = c
        self.speedx = speedx
        self.speedy = speedy

    def draw(self, painter):
        self.x += self.speedx
        self.y += self.speedy

        painter.setBrush(self.c)
        painter.setPen(self.c)
        painter.drawEllipse(QRectF(self.x, self.y, self.w, self.h))

# Line 클래스
class Line():
    def __init__(self, ix, iy, c, angle):
        # 선의 시작점(흰 공의 중심)
        self.sx = ix + 10
        self.sy = iy + 10
        self.c = c
        self.angle = angle

    def draw(self, painter):
        # 선 방정식 구하기
        if self.angle == 0:
            self.tx = 0
            self.ty = 290
        elif self.angle != 90:
            self.a = np.tan(self.angle / 180 * np.pi)  # 기울기
            self.b = self.sy - self.a * self.sx  # 절편

            if self.a > 0:  # 기울기가 양수일 때
                # 선이 벽과 만나는 점의 좌표값
                self.tx = max(-1 * self.b / self.a, 0)
                self.ty = max(self.b, 0)

            elif self.a < 0:  # 기울기가 음수일 때
                # 선과 벽이 만나는 점의 좌표값
                self.tx = min(-1 * self.b / self.a, 400)
                self.ty = max(0, 400 * self.a + self.b)

        else:  # 각이 90도 -> 기울기 무한대
            self.tx = 210
            self.ty = 0
            self.a = 9999
            self.b = 0

        painter.setPen(self.c)
        painter.drawLine(self.sx, self.sy, self.tx, self.ty)

# Game Class
class MainWindowA(QMainWindow):
    def __init__(self):
        super().__init__()

        self.label = QLabel()

        canvas = QPixmap(400, 300)
        self.label.setPixmap(canvas)
        self.setCentralWidget(self.label)

        self.redBall = Ball(0, 0, 10, 10, Qt.red, 0, 0)
        self.whtBall = Ball(200, 250, 20, 20, Qt.white, 0, 0)
        self.shtLine = Line(200, 280, Qt.cyan, 90)

        self.timecounter = 0
        self.init_ball()
        self.explosion = False

        self.exp_img = QImage('exp.png')
        # self.collide = False
        self.timer = None
        self.exp_pos = QPointF(0.0, 0.0)

        self.firing = False

        self.timer_start()

    def draw(self):
        self.timecounter += 1
        painter = QPainter(self.label.pixmap())
        painter.fillRect(0, 0, 400, 300, QBrush(Qt.black))

        self.shtLine.draw(painter)
        self.redBall.draw(painter)
        self.whtBall.draw(painter)

        if self.firing:
            painter.setPen(Qt.red)  # 빔 발사
            painter.drawLine(self.shtLine.sx, self.shtLine.sy, self.shtLine.tx, self.shtLine.ty)
            self.whtBall.draw(painter)

        if self.timecounter % 90 == 0:
            self.init_ball()

        if self.explosion:
            self.sprite_anim(painter)

        self.label.repaint()

        if self.collide:
            return

        # Collision Detection
        if self.firing:
            # 명중 조건 - 조준선과 빨간볼 중심 사이의 거리가 빨간공 반지름보다 작거나 같을 때
            if np.abs(self.shtLine.a * (self.redBall.x+self.redBall.w/2) -\
                    self.redBall.y+self.redBall.h/2+ self.shtLine.b)/np.sqrt(
                self.shtLine.a**2 + 1) <= self.redBall.w/2:
                #print('명중')
                #print('빨간공 위치(%d, %d), 선 각도 %d, 기울기 %f, 절편 %f' % (self.redBall.x, self.redBall.y,
                #                                                  self.shtLine.angle, self.shtLine.a, self.shtLine.b))
                self.timecounter = 0
                self.firing = False
                self.collide = True
                if not self.explosion:
                    self.explosion = True
                    self.exp_pos.x = self.redBall.x - 20  # 폭발 위치
                    self.exp_pos.y = self.redBall.y - 20
                    self.init_ball()
            else:
                # print('불발')
                # print('빨간공 위치(%d, %d), 선 각도 %d, 기울기 %f, 절편 %f' % (self.redBall.x, self.redBall.y,
                #                                                  self.shtLine.angle, self.shtLine.a, self.shtLine.b))
                self.firing = False

    def init_ball(self):
        self.redBall.x = np.random.uniform(low=0, high=380, size=1)
        self.redBall.y = 0
        self.whtBall.y = 280
        self.whtBall.speedy = 0
        self.collide = False
        print('init_ball()')

    def timer_start(self):
        self.timer = QTimer()
        self.timer.setInterval(30)
        self.timer.timeout.connect(self.draw)
        self.timer.start()

    def timer_stop(self):
        self.timer.stop()

    def keyPressEvent(self, evt):
        if evt.key() == Qt.Key_Space:
            self.fire()
        if evt.key() == Qt.Key_Right:
            self.move_right()
        elif evt.key() == Qt.Key_Left:
            self.move_left()

    def sprite_anim(self, painter):
        s = 62
        target = QRectF(self.exp_pos.x, self.exp_pos.y, 62.0, 62.0)
        source = QRectF(0, 0, 62.0, 62.0)  # 폭발 스프라이트의 첫 프레임만 표시한다
        painter.drawImage(target, self.exp_img, source)

        self.explosion = False

    def move_right(self):
        self.shtLine.angle += 1
        # print(self.shtLine.angle)

    def move_left(self):
        self.shtLine.angle -= 1
        # print(self.shtLine.angle)

    def fire(self):
        self.firing = True


#app = QApplication(sys.argv)
#window = MainWindowA()
#window.show()
#app.exec_()
# Out:
# init_ball()
# init_ball()
# <ipython-input-1-e55acaa8880f>:63: DeprecationWarning: an integer is required (got type numpy.float64).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   painter.drawLine(self.sx, self.sy, self.tx, self.ty)
# init_ball()
# <ipython-input-1-e55acaa8880f>:104: DeprecationWarning: an integer is required (got type numpy.float64).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   painter.drawLine(self.shtLine.sx, self.shtLine.sy, self.shtLine.tx, self.shtLine.ty)
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# 0

# %%
# Environment Class

import gym
from gym import spaces
import numpy as np
import threading
import time
import sys
from PyQt5.QtWidgets import *

# Agent 가 학습할 때 사용하는 환경을 제공하는 클래스
# Agent 는 학습을 위해 이 클래스의 멤버변수인 action_space, observation_sapace 를 사용하고
# step(), reset() 함수를 호출할 것이므로 이들 변수와 함수를 통해서 게임이 시작되어 작동하며
# 종료될 수 있어야 한다.
# 이 게임은 step()함수가 1000번 호출되면 1회의 에피소드가 실행된 것으로 작성하였다

class GameEnv(gym.Env):
    """Custom Environment that follows gym interface"""
    metadata = {'render.modes': ['human']}

    def __init__(self):
        super(GameEnv, self).__init__()

        # Define action and observation space
        # They must be gym.spaces objects
        # Example when using discrete actions:
        #self.action_space = spaces.Discrete(N_DISCRETE_ACTIONS)
        # Example for using image as input:
        #self.observation_space = spaces.Box(low=0, high=380, shape=
        #(HEIGHT, WIDTH, N_CHANNELS), dtype=np.uint8)

        self.action_space = spaces.Discrete(3)
        self.observation_space = spaces.Box(low=0, high=380, shape=(2,), dtype=np.float32)

        self.score = 0
        self.total_scores = 0
        self.done = False
        self.counts = 0

        #게임 클래스에 게임루프(무한루프)가 실행되므로 현재 코드와 동시에 실행하도록 하려면 Thread 가 필요함
        self.game = None
        self.game_thread = threading.Thread(target=self.game_window)
        #self.game_thread.daemon = True   # 여기서는 절대 사용 금지
        self.game_thread.start()

        print('Env 생성')

    # 게임을 쓰레드로 실행하기 위해 함수에 포함
    def game_window(self):
        app = QApplication(sys.argv)
        self.game = MainWindowA()
        self.game.show()
        app.exec_()

    def step(self, action):
        self.score = 0
        if action==0:
            if self.game.shtLine.angle >= 0:
                self.game.move_left()
                if self.game.redBall.x + self.game.redBall.w < self.game.shtLine.tx:
                    self.score = 1
        elif action==1:
            if self.game.shtLine.angle <= 180:
                self.game.move_right()
                if self.game.redBall.x + self.game.redBall.w > self.game.shtLine.tx:
                    self.score = 1
        elif action==2:
            self.game.fire()
            if np.abs(self.game.shtLine.a * (self.game.redBall.x+self.game.redBall.w/2) -\
                    self.game.redBall.y+self.game.redBall.h/2+ self.game.shtLine.b)/np.sqrt(
                self.game.shtLine.a**2 + 1) <= self.game.redBall.w/2:
                self.score = 1
                
        self.counts += 1
        
        if self.counts == 1000:
            self.done = True
            
        self.total_scores += self.score
        obs = [self.game.redBall.x, self.game.shtLine.tx]
        return obs, self.score, self.done, {}

    def render(self, mode='human'):
        pass

    def reset(self):
        self.total_scores = 0
        self.counts = 0
        self.done = False
        self.game.init_ball()
        obs = [self.game.redBall.x, self.game.shtLine.tx]
        return obs

    # Env 작동 테스트
    def test(self):
        while not self.game:
            time.sleep(0.1)
        for i in range(1, 101):  # 100회의 에피소드 테스트
            obs = self.reset()

            while not self.done:
                action = self.action_space.sample()
                obs, score, done, _ = self.step(action)
                print('Episode:', i, 'Step:', self.counts, 'Score:',self.score, 'Total Score:', self.total_scores)
                time.sleep(0.03)


#gameEnv = GameEnv()
#gameEnv.test()
# Out:
# Env 생성
# init_ball()
# init_ball()
# Episode: 1 Step: 1 Score: 0 Total Score: 0
# Episode: 1 Step: 2 Score: 0 Total Score: 0
# Episode:
# <ipython-input-1-9fbb20707f25>:63: DeprecationWarning: an integer is required (got type numpy.float64).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   painter.drawLine(self.sx, self.sy, self.tx, self.ty)
# <ipython-input-1-9fbb20707f25>:104: DeprecationWarning: an integer is required (got type numpy.float64).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   painter.drawLine(self.shtLine.sx, self.shtLine.sy, self.shtLine.tx, self.shtLine.ty)
#  1 Step: 3 Score: 0 Total Score: 0
# Episode: 1 Step: 4 Score: 0 Total Score: 0
# Episode: 1 Step: 5 Score: 0 Total Score: 0
# Episode: 1 Step: 6 Score: 0 Total Score: 0
# Episode: 1 Step: 7 Score: 1 Total Score: 1
# Episode: 1 Step: 8 Score: 0 Total Score: 1
# Episode: 1 Step: 9 Score: 0 Total Score: 1
# Episode: 1 Step: 10 Score: 0 Total Score: 1
# Episode: 1 Step: 11 Score: 1 Total Score: 2
# Episode: 1 Step: 12 Score: 0 Total Score: 2
# Episode: 1 Step: 13 Score: 1 Total Score: 3
# Episode: 1 Step: 14 Score: 1 Total Score: 4
# Episode: 1 Step: 15 Score: 0 Total Score: 4
# Episode: 1 Step: 16 Score: 0 Total Score: 4
# Episode: 1 Step: 17 Score: 0 Total Score: 4
# Episode: 1 Step: 18 Score: 0 Total Score: 4
# Episode: 1 Step: 19 Score: 1 Total Score: 5
# Episode: 1 Step: 20 Score: 0 Total Score: 5
# Episode: 1 Step: 21 Score: 0 Total Score: 5
# Episode: 1 Step: 22 Score: 0 Total Score: 5
# Episode: 1 Step: 23 Score: 0 Total Score: 5
# Episode: 1 Step: 24 Score: 0 Total Score: 5
# Episode: 1 Step: 25 Score: 0 Total Score: 5
# Episode: 1 Step: 26 Score: 0 Total Score: 5
# Episode: 1 Step: 27 Score: 0 Total Score: 5
# Episode: 1 Step: 28 Score: 0 Total Score: 5
# Episode: 1 Step: 29 Score: 0 Total Score: 5
# Episode: 1 Step: 30 Score: 0 Total Score: 5
# Episode: 1 Step: 31 Score: 0 Total Score: 5
# Episode: 1 Step: 32 Score: 0 Total Score: 5
# Episode: 1 Step: 33 Score: 1 Total Score: 6
# Episode: 1 Step: 34 Score: 0 Total Score: 6
# Episode: 1 Step: 35 Score: 1 Total Score: 7
# Episode: 1 Step: 36 Score: 0 Total Score: 7
# Episode: 1 Step: 37 Score: 0 Total Score: 7
# Episode: 1 Step: 38 Score: 0 Total Score: 7
# Episode: 1 Step: 39 Score: 1 Total Score: 8
# Episode: 1 Step: 40 Score: 0 Total Score: 8
# Episode: 1 Step: 41 Score: 0 Total Score: 8
# Episode: 1 Step: 42 Score: 0 Total Score: 8
# Episode: 1 Step: 43 Score: 1 Total Score: 9
# Episode: 1 Step: 44 Score: 1 Total Score: 10
# Episode: 1 Step: 45 Score: 0 Total Score: 10
# Episode: 1 Step: 46 Score: 0 Total Score: 10
# Episode: 1 Step: 47 Score: 0 Total Score: 10
# Episode: 1 Step: 48 Score: 1 Total Score: 11
# Episode: 1 Step: 49 Score: 1 Total Score: 12
# Episode: 1 Step: 50 Score: 1 Total Score: 13
# Episode: 1 Step: 51 Score: 0 Total Score: 13
# Episode: 1 Step: 52 Score: 1 Total Score: 14
# Episode: 1 Step: 53 Score: 1 Total Score: 15
# Episode: 1 Step: 54 Score: 0 Total Score: 15
# Episode: 1 Step: 55 Score: 0 Total Score: 15
# Episode: 1 Step: 56 Score: 0 Total Score: 15
# Episode: 1 Step: 57 Score: 0 Total Score: 15
# Episode: 1 Step: 58 Score: 1 Total Score: 16
# Episode: 1 Step: 59 Score: 0 Total Score: 16
# Episode: 1 Step: 60 Score: 0 Total Score: 16
# Episode: 1 Step: 61 Score: 1 Total Score: 17
# Episode: 1 Step: 62 Score: 0 Total Score: 17
# Episode: 1 Step: 63 Score: 0 Total Score: 17
# Episode: 1 Step: 64 Score: 0 Total Score: 17
# Episode: 1 Step: 65 Score: 0 Total Score: 17
# Episode: 1 Step: 66 Score: 1 Total Score: 18
# Episode: 1 Step: 67 Score: 0 Total Score: 18
# Episode: 1 Step: 68 Score: 1 Total Score: 19
# Episode: 1 Step: 69 Score: 1 Total Score: 20
# Episode: 1 Step: 70 Score: 1 Total Score: 21
# Episode: 1 Step: 71 Score: 0 Total Score: 21
# Episode: 1 Step: 72 Score: 0 Total Score: 21
# Episode: 1 Step: 73 Score: 0 Total Score: 21
# Episode: 1 Step: 74 Score: 0 Total Score: 21
# Episode: 1 Step: 75 Score: 0 Total Score: 21
# Episode: 1 Step: 76 Score: 1 Total Score: 22
# Episode: 1 Step: 77 Score: 0 Total Score: 22
# Episode: 1 Step: 78 Score: 1 Total Score: 23
# Episode: 1 Step: 79 Score: 0 Total Score: 23
# Episode: 1 Step: 80 Score: 1 Total Score: 24
# Episode: 1 Step: 81 Score: 0 Total Score: 24
# Episode: 1 Step: 82 Score: 0 Total Score: 24
# Episode: 1 Step: 83 Score: 1 Total Score: 25
# Episode: 1 Step: 84 Score: 0 Total Score: 25
# Episode: 1 Step: 85 Score: 0 Total Score: 25
# init_ball()
# Episode: 1 Step: 86 Score: 0 Total Score: 25
# Episode: 1 Step: 87 Score: 1 Total Score: 26
# Episode: 1 Step: 88 Score: 0 Total Score: 26
# Episode: 1 Step: 89 Score: 0 Total Score: 26
# Episode: 1 Step: 90 Score: 0 Total Score: 26
# Episode: 1 Step: 91 Score: 0 Total Score: 26
# Episode: 1 Step: 92 Score: 0 Total Score: 26
# Episode: 1 Step: 93 Score: 1 Total Score: 27
# Episode: 1 Step: 94 Score: 1 Total Score: 28
# Episode: 1 Step: 95 Score: 0 Total Score: 28
# Episode: 1 Step: 96 Score: 0 Total Score: 28
# Episode: 1 Step: 97 Score: 0 Total Score: 28
# Episode: 1 Step: 98 Score: 1 Total Score: 29
# Episode: 1 Step: 99 Score: 1 Total Score: 30
# Episode: 1 Step: 100 Score: 0 Total Score: 30
# Episode: 1 Step: 101 Score: 0 Total Score: 30
# Episode: 1 Step: 102 Score: 1 Total Score: 31
# Episode: 1 Step: 103 Score: 0 Total Score: 31
# Episode: 1 Step: 104 Score: 0 Total Score: 31
# Episode: 1 Step: 105 Score: 1 Total Score: 32
# Episode: 1 Step: 106 Score: 0 Total Score: 32
# Episode: 1 Step: 107 Score: 0 Total Score: 32
# Episode: 1 Step: 108 Score: 0 Total Score: 32
# Episode: 1 Step: 109 Score: 0 Total Score: 32
# Episode: 1 Step: 110 Score: 1 Total Score: 33
# Episode: 1 Step: 111 Score: 0 Total Score: 33
# Episode: 1 Step: 112 Score: 0 Total Score: 33
# Episode: 1 Step: 113 Score: 0 Total Score: 33
# Episode: 1 Step: 114 Score: 0 Total Score: 33
# Episode: 1 Step: 115 Score: 0 Total Score: 33
# Episode: 1 Step: 116 Score: 0 Total Score: 33
# Episode: 1 Step: 117 Score: 0 Total Score: 33
# Episode: 1 Step: 118 Score: 0 Total Score: 33
# Episode: 1 Step: 119 Score: 1 Total Score: 34
# Episode: 1 Step: 120 Score: 0 Total Score: 34
# Episode: 1 Step: 121 Score: 1 Total Score: 35
# Episode: 1 Step: 122 Score: 0 Total Score: 35
# Episode: 1 Step: 123 Score: 1 Total Score: 36
# Episode: 1 Step: 124 Score: 0 Total Score: 36
# Episode: 1 Step: 125 Score: 0 Total Score: 36
# Episode: 1 Step: 126 Score: 0 Total Score: 36
# Episode: 1 Step: 127 Score: 0 Total Score: 36
# Episode: 1 Step: 128 Score: 0 Total Score: 36
# Episode: 1 Step: 129 Score: 0 Total Score: 36
# Episode: 1 Step: 130 Score: 0 Total Score: 36
# Episode: 1 Step: 131 Score: 1 Total Score: 37
# Episode: 1 Step: 132 Score: 0 Total Score: 37
# Episode: 1 Step: 133 Score: 0 Total Score: 37
# Episode: 1 Step: 134 Score: 0 Total Score: 37
# Episode: 1 Step: 135 Score: 0 Total Score: 37
# Episode: 1 Step: 136 Score: 0 Total Score: 37
# Episode: 1 Step: 137 Score: 0 Total Score: 37
# Episode: 1 Step: 138 Score: 0 Total Score: 37
# Episode: 1 Step: 139 Score: 0 Total Score: 37
# Episode: 1 Step: 140 Score: 0 Total Score: 37
# Episode: 1 Step: 141 Score: 0 Total Score: 37
# Episode: 1 Step: 142 Score: 0 Total Score: 37
# Episode: 1 Step: 143 Score: 1 Total Score: 38
# Episode: 1 Step: 144 Score: 1 Total Score: 39
# Episode: 1 Step: 145 Score: 0 Total Score: 39
# Episode: 1 Step: 146 Score: 0 Total Score: 39
# Episode: 1 Step: 147 Score: 0 Total Score: 39
# Episode: 1 Step: 148 Score: 1 Total Score: 40
# Episode: 1 Step: 149 Score: 0 Total Score: 40
# Episode: 1 Step: 150 Score: 0 Total Score: 40
# Episode: 1 Step: 151 Score: 1 Total Score: 41
# Episode: 1 Step: 152 Score: 0 Total Score: 41
# Episode: 1 Step: 153 Score: 1 Total Score: 42
# Episode: 1 Step: 154 Score: 1 Total Score: 43
# Episode: 1 Step: 155 Score: 1 Total Score: 44
# Episode: 1 Step: 156 Score: 0 Total Score: 44
# Episode: 1 Step: 157 Score: 0 Total Score: 44
# Episode: 1 Step: 158 Score: 0 Total Score: 44
# Episode: 1 Step: 159 Score: 0 Total Score: 44
# Episode: 1 Step: 160 Score: 0 Total Score: 44
# Episode: 1 Step: 161 Score: 1 Total Score: 45
# Episode: 1 Step: 162 Score: 0 Total Score: 45
# Episode: 1 Step: 163 Score: 0 Total Score: 45
# Episode: 1 Step: 164 Score: 1 Total Score: 46
# Episode: 1 Step: 165 Score: 0 Total Score: 46
# Episode: 1 Step: 166 Score: 0 Total Score: 46
# Episode: 1 Step: 167 Score: 0 Total Score: 46
# Episode: 1 Step: 168 Score: 1 Total Score: 47
# Episode: 1 Step: 169 Score: 0 Total Score: 47
# Episode: 1 Step: 170 Score: 1 Total Score: 48
# Episode: 1 Step: 171 Score: 0 Total Score: 48
# Episode:init_ball() 1 Step: 172 Score: 0 Total Score: 48
#
# Episode: 1 Step: 173 Score: 0 Total Score: 48
# Episode: 1 Step: 174 Score: 1 Total Score: 49
# Episode: 1 Step: 175 Score: 0 Total Score: 49
# Episode: 1 Step: 176 Score: 0 Total Score: 49
# Episode: 1 Step: 177 Score: 0 Total Score: 49
# Episode: 1 Step: 178 Score: 0 Total Score: 49
# Episode: 1 Step: 179 Score: 0 Total Score: 49
# Episode: 1 Step: 180 Score: 0 Total Score: 49
# Episode: 1 Step: 181 Score: 0 Total Score: 49
# Episode: 1 Step: 182 Score: 0 Total Score: 49
# Episode: 1 Step: 183 Score: 1 Total Score: 50
# Episode: 1 Step: 184 Score: 0 Total Score: 50
# Episode: 1 Step: 185 Score: 0 Total Score: 50
# Episode: 1 Step: 186 Score: 0 Total Score: 50
# Episode: 1 Step: 187 Score: 1 Total Score: 51
# Episode: 1 Step: 188 Score: 0 Total Score: 51
# Episode: 1 Step: 189 Score: 1 Total Score: 52
# Episode: 1 Step: 190 Score: 0 Total Score: 52
# Episode: 1 Step: 191 Score: 1 Total Score: 53
# Episode: 1 Step: 192 Score: 1 Total Score: 54
# Episode: 1 Step: 193 Score: 0 Total Score: 54
# Episode: 1 Step: 194 Score: 1 Total Score: 55
# Episode: 1 Step: 195 Score: 0 Total Score: 55
# Episode: 1 Step: 196 Score: 1 Total Score: 56
# Episode: 1 Step: 197 Score: 0 Total Score: 56
# Episode: 1 Step: 198 Score: 0 Total Score: 56
# Episode: 1 Step: 199 Score: 0 Total Score: 56
# Episode: 1 Step: 200 Score: 0 Total Score: 56
# Episode: 1 Step: 201 Score: 0 Total Score: 56
# Episode: 1 Step: 202 Score: 1 Total Score: 57
# Episode: 1 Step: 203 Score: 0 Total Score: 57
# Episode: 1 Step: 204 Score: 0 Total Score: 57
# Episode: 1 Step: 205 Score: 0 Total Score: 57
# Episode: 1 Step: 206 Score: 0 Total Score: 57
# Episode: 1 Step: 207 Score: 1 Total Score: 58
# Episode: 1 Step: 208 Score: 0 Total Score: 58
# Episode: 1 Step: 209 Score: 0 Total Score: 58
# Episode: 1 Step: 210 Score: 0 Total Score: 58
# Episode: 1 Step: 211 Score: 1 Total Score: 59
# Episode: 1 Step: 212 Score: 1 Total Score: 60
# Episode: 1 Step: 213 Score: 0 Total Score: 60
# Episode: 1 Step: 214 Score: 0 Total Score: 60
# Episode: 1 Step: 215 Score: 0 Total Score: 60
# Episode: 1 Step: 216 Score: 1 Total Score: 61
# Episode: 1 Step: 217 Score: 0 Total Score: 61
# Episode: 1 Step: 218 Score: 1 Total Score: 62
# Episode: 1 Step: 219 Score: 1 Total Score: 63
# Episode: 1 Step: 220 Score: 0 Total Score: 63
# Episode: 1 Step: 221 Score: 0 Total Score: 63
# Episode: 1 Step: 222 Score: 1 Total Score: 64
# Episode: 1 Step: 223 Score: 1 Total Score: 65
# Episode: 1 Step: 224 Score: 0 Total Score: 65
# Episode: 1 Step: 225 Score: 1 Total Score: 66
# Episode: 1 Step: 226 Score: 1 Total Score: 67
# Episode: 1 Step: 227 Score: 0 Total Score: 67
# Episode: 1 Step: 228 Score: 1 Total Score: 68
# Episode: 1 Step: 229 Score: 0 Total Score: 68
# Episode: 1 Step: 230 Score: 0 Total Score: 68
# Episode: 1 Step: 231 Score: 0 Total Score: 68
# Episode: 1 Step: 232 Score: 0 Total Score: 68
# Episode: 1 Step: 233 Score: 0 Total Score: 68
# Episode: 1 Step: 234 Score: 1 Total Score: 69
# Episode: 1 Step: 235 Score: 0 Total Score: 69
# Episode: 1 Step: 236 Score: 1 Total Score: 70
# Episode: 1 Step: 237 Score: 1 Total Score: 71
# Episode: 1 Step: 238 Score: 0 Total Score: 71
# Episode: 1 Step: 239 Score: 0 Total Score: 71
# Episode: 1 Step: 240 Score: 1 Total Score: 72
# Episode: 1 Step: 241 Score: 1 Total Score: 73
# Episode: 1 Step: 242 Score: 0 Total Score: 73
# Episode: 1 Step: 243 Score: 1 Total Score: 74
# Episode: 1 Step: 244 Score: 0 Total Score: 74
# Episode: 1 Step: 245 Score: 0 Total Score: 74
# Episode: 1 Step: 246 Score: 0 Total Score: 74
# Episode: 1 Step: 247 Score: 0 Total Score: 74
# Episode: 1 Step: 248 Score: 0 Total Score: 74
# Episode: 1 Step: 249 Score: 1 Total Score: 75
# Episode: 1 Step: 250 Score: 0 Total Score: 75
# Episode: 1 Step: 251 Score: 0 Total Score: 75
# Episode: 1 Step: 252 Score: 0 Total Score: 75
# Episode: 1 Step: 253 Score: 0 Total Score: 75
# Episode: 1 Step: 254 Score: 0 Total Score: 75
# Episode: 1 Step: 255 Score: 0 Total Score: 75
# Episode: 1 Step: 256 Score: 1 Total Score: 76
# Episode: 1 Step: 257 Score: 0 Total Score: 76
# Episode: 1 Step: 258 Score: 0 Total Score: 76
# Episode: 1 Step: 259 Score: 0 Total Score: 76
# Episode: 1 Step: 260 Score: 1 Total Score: 77
# Episode: 1 Step: 261 Score: 0 Total Score: 77
# Episode: 1 Step: 262 Score: 0 Total Score: 77
# Episode: 1 Step: 263 Score: 1 Total Score: 78
# Episode: 1 Step: 264 Score: 0 Total Score: 78
# Episode: 1 Step: 265 Score: 1 Total Score: 79
# Episode: 1 Step: 266 Score: 1 Total Score: 80
# Episode: 1 Step: 267 Score: 0 Total Score: 80
# Episode: 1 Step: 268 Score: 1 Total Score: 81
# Episode: 1 Step: 269 Score: 0 Total Score: 81
# Episode: 1 Step: 270 Score: 1 Total Score: 82
# Episode: 1 Step: 271 Score: 1 Total Score: 83
# Episode: 1 Step: 272 Score: 1 Total Score: 84
# Episode: 1 Step: 273 Score: 1 Total Score: 85
# Episode: 1 Step: 274 Score: 1 Total Score: 86
# Episode: 1 Step: 275 Score: 0 Total Score: 86
# Episode: 1 Step: 276 Score: 0 Total Score: 86
# Episode: 1 Step: 277 Score: 0 Total Score: 86
# Episode: 1 Step: 278 Score: 0 Total Score: 86
# Episode: 1 Step: 279 Score: 0 Total Score: 86
# Episode: 1 Step: 280 Score: 0 Total Score: 86
# Episode: 1 Step: 281 Score: 0 Total Score: 86
# Episode: 1 Step: 282 Score: 0 Total Score: 86
# Episode: 1 Step: 283 Score: 0 Total Score: 86
# Episode: 1 Step: 284 Score: 0 Total Score: 86
# Episode: 1 Step: 285 Score: 1 Total Score: 87
# Episode: 1 Step: 286 Score: 0 Total Score: 87
# Episode: 1 Step: 287 Score: 1 Total Score: 88
# Episode: 1 Step: 288 Score: 0 Total Score: 88
# Episode: 1 Step: 289 Score: 1 Total Score: 89
# Episode: 1 Step: 290 Score: 0 Total Score: 89
# Episode: 1 Step: 291 Score: 0 Total Score: 89
# Episode: 1 Step: 292 Score: 1 Total Score: 90
# Episode: 1 Step: 293 Score: 0 Total Score: 90
# Episode: 1 Step: 294 Score: 1 Total Score: 91
# Episode: 1 Step: 295 Score: 1 Total Score: 92
# Episode: 1 Step: 296 Score: 0 Total Score: 92
# Episode: 1 Step: 297 Score: 1 Total Score: 93
# Episode: 1 Step: 298 Score: 0 Total Score: 93
# Episode: 1 Step: 299 Score: 1 Total Score: 94
# Episode: 1 Step: 300 Score: 0 Total Score: 94
# Episode: 1 Step: 301 Score: 0 Total Score: 94
# Episode: 1 Step: 302 Score: 0 Total Score: 94
# Episode: 1 Step: 303 Score: 0 Total Score: 94
# Episode: 1 Step: 304 Score: 0 Total Score: 94
# Episode: 1 Step: 305 Score: 0 Total Score: 94
# Episode: 1 Step: 306 Score: 0 Total Score: 94
# Episode: 1 Step: 307 Score: 0 Total Score: 94
# Episode: 1 Step: 308 Score: 0 Total Score: 94
# Episode: 1 Step: 309 Score: 0 Total Score: 94
# Episode: 1 Step: 310 Score: 1 Total Score: 95
# Episode: 1 Step: 311 Score: 0 Total Score: 95
# Episode: 1 Step: 312 Score: 0 Total Score: 95
# Episode: 1 Step: 313 Score: 0 Total Score: 95
# Episode: 1 Step: 314 Score: 0 Total Score: 95
# Episode: 1 Step: 315 Score: 1 Total Score: 96
# Episode: 1 Step: 316 Score: 0 Total Score: 96
# Episode: 1 Step: 317 Score: 0 Total Score: 96
# Episode: 1 Step: 318 Score: 1 Total Score: 97
# Episode: 1 Step: 319 Score: 0 Total Score: 97
# Episode: 1 Step: 320 Score: 1 Total Score: 98
# Episode: 1 Step: 321 Score: 0 Total Score: 98
# Episode: 1 Step: 322 Score: 0 Total Score: 98
# Episode: 1 Step: 323 Score: 0 Total Score: 98
# Episode: 1 Step: 324 Score: 0 Total Score: 98
# Episode: 1 Step: 325 Score: 0 Total Score: 98
# Episode: 1 Step: 326 Score: 0 Total Score: 98
# Episode: 1 Step: 327 Score: 0 Total Score: 98
# Episode: 1 Step: 328 Score: 1 Total Score: 99
# Episode: 1 Step: 329 Score: 0 Total Score: 99
# Episode: 1 Step: 330 Score: 0 Total Score: 99
# Episode: 1 Step: 331 Score: 1 Total Score: 100
# Episode: 1 Step: 332 Score: 0 Total Score: 100
# Episode: 1 Step: 333 Score: 0 Total Score: 100
# Episode: 1 Step: 334 Score: 0 Total Score: 100
# Episode: 1 Step: 335 Score: 0 Total Score: 100
# Episode: 1 Step: 336 Score: 0 Total Score: 100
# Episode: 1 Step: 337 Score: 0 Total Score: 100
# Episode: 1 Step: 338 Score: 1 Total Score: 101
# Episode: 1 Step: 339 Score: 0 Total Score: 101
# Episode: 1 Step: 340 Score: 1 Total Score: 102
# Episode: 1 Step: 341 Score: 0 Total Score: 102
# Episode: 1 Step: 342 Score: 1 Total Score: 103
# Episode: 1 Step: 343 Score: 1 Total Score: 104
# Episode: 1 Step: 344 Score: 1 Total Score: 105
# Episode: 1 Step: 345 Score: 0 Total Score: 105
# Episode: 1 Step: 346 Score: 0 Total Score: 105
# Episode: 1 Step: 347 Score: 1 Total Score: 106
# Episode: 1 Step: 348 Score: 1 Total Score: 107
# Episode: 1 Step: 349 Score: 1 Total Score: 108
# Episode: 1 Step: 350 Score: 1 Total Score: 109
# Episode: 1 Step: 351 Score: 0 Total Score: 109
# Episode: 1 Step: 352 Score: 1 Total Score: 110
# Episode: 1 Step: 353 Score: 1 Total Score: 111
# Episode: 1 Step: 354 Score: 1 Total Score: 112
# Episode: 1 Step: 355 Score: 1 Total Score: 113
# Episode: 1 Step: 356 Score: 0 Total Score: 113
# Episode: 1 Step: 357 Score: 1 Total Score: 114
# Episode: 1 Step: 358 Score: 0 Total Score: 114
# Episode: 1 Step: 359 Score: 0 Total Score: 114
# Episode: 1 Step: 360 Score: 0 Total Score: 114
# Episode: 1 Step: 361 Score: 0 Total Score: 114
# Episode: 1 Step: 362 Score: 0 Total Score: 114
# Episode: 1 Step: 363 Score: 0 Total Score: 114
# Episode: 1 Step: 364 Score: 1 Total Score: 115
# Episode: 1 Step: 365 Score: 1 Total Score: 116
# Episode: 1 Step: 366 Score: 0 Total Score: 116
# Episode: 1 Step: 367 Score: 0 Total Score: 116
# Episode: 1 Step: 368 Score: 0 Total Score: 116
# Episode: 1 Step: 369 Score: 1 Total Score: 117
# Episode: 1 Step: 370 Score: 1 Total Score: 118
# Episode: 1 Step: 371 Score: 1 Total Score: 119
# Episode: 1 Step: 372 Score: 0 Total Score: 119
# Episode: 1 Step: 373 Score: 0 Total Score: 119
# Episode: 1 Step: 374 Score: 1 Total Score: 120
# Episode: 1 Step: 375 Score: 0 Total Score: 120
# Episode: 1 Step: 376 Score: 1 Total Score: 121
# Episode: 1 Step: 377 Score: 0 Total Score: 121
# Episode: 1 Step: 378 Score: 0 Total Score: 121
# Episode: 1 Step: 379 Score: 0 Total Score: 121
# Episode: 1 Step: 380 Score: 1 Total Score: 122
# Episode: 1 Step: 381 Score: 1 Total Score: 123
# Episode: 1 Step: 382 Score: 1 Total Score: 124
# Episode: 1 Step: 383 Score: 0 Total Score: 124
# Episode: 1 Step: 384 Score: 1 Total Score: 125
# Episode: 1 Step: 385 Score: 0 Total Score: 125
# Episode: 1 Step: 386 Score: 0 Total Score: 125
# Episode: 1 Step: 387 Score: 1 Total Score: 126
# Episode: 1 Step: 388 Score: 0 Total Score: 126
# Episode: 1 Step: 389 Score: 0 Total Score: 126
# Episode: 1 Step: 390 Score: 0 Total Score: 126
# Episode: 1 Step: 391 Score: 0 Total Score: 126
# Episode: 1 Step: 392 Score: 0 Total Score: 126
# Episode: 1 Step: 393 Score: 1 Total Score: 127
# Episode: 1 Step: 394 Score: 1 Total Score: 128
# Episode: 1 Step: 395 Score: 1 Total Score: 129
# Episode: 1 Step: 396 Score: 0 Total Score: 129
# Episode: 1 Step: 397 Score: 0 Total Score: 129
# Episode: 1 Step: 398 Score: 0 Total Score: 129
# Episode: 1 Step: 399 Score: 0 Total Score: 129
# Episode: 1 Step: 400 Score: 0 Total Score: 129
# Episode: 1 Step: 401 Score: 0 Total Score: 129
# Episode: 1 Step: 402 Score: 0 Total Score: 129
# Episode: 1 Step: 403 Score: 1 Total Score: 130
# Episode: 1 Step: 404 Score: 0 Total Score: 130
# Episode: 1 Step: 405 Score: 0 Total Score: 130
# Episode: 1 Step: 406 Score: 1 Total Score: 131
# Episode: 1 Step: 407 Score: 0 Total Score: 131
# Episode: 1 Step: 408 Score: 0 Total Score: 131
# Episode: 1 Step: 409 Score: 1 Total Score: 132
# Episode: 1 Step: 410 Score: 0 Total Score: 132
# Episode: 1 Step: 411 Score: 0 Total Score: 132
# Episode: 1 Step: 412 Score: 0 Total Score: 132
# Episode: 1 Step: 413 Score: 1 Total Score: 133
# Episode: 1 Step: 414 Score: 1 Total Score: 134
# Episode: 1 Step: 415 Score: 0 Total Score: 134
# Episode: 1 Step: 416 Score: 1 Total Score: 135
# Episode: 1 Step: 417 Score: 1 Total Score: 136
# Episode: 1 Step: 418 Score: 1 Total Score: 137
# Episode: 1 Step: 419 Score: 0 Total Score: 137
# Episode: 1 Step: 420 Score: 1 Total Score: 138
# Episode: 1 Step: 421 Score: 1 Total Score: 139
# Episode: 1 Step: 422 Score: 1 Total Score: 140
# Episode: 1 Step: 423 Score: 0 Total Score: 140
# Episode: 1 Step: 424 Score: 1 Total Score: 141
# Episode: 1 Step: 425 Score: 0 Total Score: 141
# Episode: 1 Step: 426 Score: 0 Total Score: 141
# Episode: 1 Step: 427 Score: 0 Total Score: 141
# Episode: 1 Step: 428 Score: 0 Total Score: 141
# Episode: 1 Step: 429 Score: 1 Total Score: 142
# Episode: 1 Step: 430 Score: 0 Total Score: 142
# Episode: 1 Step: 431 Score: 1 Total Score: 143
# Episode: 1 Step: 432 Score: 1 Total Score: 144
# Episode: 1 Step: 433 Score: 0 Total Score: 144
# Episode: 1 Step: 434 Score: 0 Total Score: 144
# Episode: 1 Step: 435 Score: 0 Total Score: 144
# Episode: 1 Step: 436 Score: 0 Total Score: 144
# Episode: 1 Step: 437 Score: 0 Total Score: 144
# Episode: 1 Step: 438 Score: 1 Total Score: 145
# Episode: 1 Step: 439 Score: 1 Total Score: 146
# Episode: 1 Step: 440 Score: 0 Total Score: 146
# Episode: 1 Step: 441 Score: 0 Total Score: 146
# Episode: 1 Step: 442 Score: 1 Total Score: 147
# Episode: 1 Step: 443 Score: 0 Total Score: 147
# Episode: 1 Step: 444 Score: 0 Total Score: 147
# Episode: 1 Step: 445 Score: 0 Total Score: 147
# Episode: 1 Step: 446 Score: 1 Total Score: 148
# Episode: 1 Step: 447 Score: 0 Total Score: 148
# Episode: 1 Step: 448 Score: 0 Total Score: 148
# Episode: 1 Step: 449 Score: 1 Total Score: 149
# Episode: 1 Step: 450 Score: 0 Total Score: 149
# Episode: 1 Step: 451 Score: 0 Total Score: 149
# Episode: 1 Step: 452 Score: 0 Total Score: 149
# Episode: 1 Step: 453 Score: 0 Total Score: 149
# Episode: 1 Step: 454 Score: 0 Total Score: 149
# Episode: 1 Step: 455 Score: 0 Total Score: 149
# Episode: 1 Step: 456 Score: 0 Total Score: 149
# Episode: 1 Step: 457 Score: 0 Total Score: 149
# Episode: 1 Step: 458 Score: 0 Total Score: 149
# Episode: 1 Step: 459 Score: 1 Total Score: 150
# Episode: 1 Step: 460 Score: 0 Total Score: 150
# Episode: 1 Step: 461 Score: 0 Total Score: 150
# Episode: 1 Step: 462 Score: 1 Total Score: 151
# Episode: 1 Step: 463 Score: 0 Total Score: 151
# Episode: 1 Step: 464 Score: 0 Total Score: 151
# Episode: 1 Step: 465 Score: 0 Total Score: 151
# Episode: 1 Step: 466 Score: 0 Total Score: 151
# Episode: 1 Step: 467 Score: 0 Total Score: 151
# Episode: 1 Step: 468 Score: 1 Total Score: 152
# Episode: 1 Step: 469 Score: 0 Total Score: 152
# Episode: 1 Step: 470 Score: 1 Total Score: 153
# Episode: 1 Step: 471 Score: 1 Total Score: 154
# Episode: 1 Step: 472 Score: 1 Total Score: 155
# Episode: 1 Step: 473 Score: 0 Total Score: 155
# Episode: 1 Step: 474 Score: 0 Total Score: 155
# Episode: 1 Step: 475 Score: 1 Total Score: 156
# Episode: 1 Step: 476 Score: 0 Total Score: 156
# Episode: 1 Step: 477 Score: 0 Total Score: 156
# Episode: 1 Step: 478 Score: 0 Total Score: 156
# Episode: 1 Step: 479 Score: 0 Total Score: 156
# Episode: 1 Step: 480 Score: 0 Total Score: 156
# Episode: 1 Step: 481 Score: 0 Total Score: 156
# Episode: 1 Step: 482 Score: 0 Total Score: 156
# Episode: 1 Step: 483 Score: 0 Total Score: 156
# Episode: 1 Step: 484 Score: 0 Total Score: 156
# Episode: 1 Step: 485 Score: 1 Total Score: 157
# Episode: 1 Step: 486 Score: 0 Total Score: 157
# Episode: 1 Step: 487 Score: 0 Total Score: 157
# Episode: 1 Step: 488 Score: 0 Total Score: 157
# Episode: 1 Step: 489 Score: 0 Total Score: 157
# Episode: 1 Step: 490 Score: 1 Total Score: 158
# Episode: 1 Step: 491 Score: 0 Total Score: 158
# Episode: 1 Step: 492 Score: 1 Total Score: 159
# Episode: 1 Step: 493 Score: 0 Total Score: 159
# Episode: 1 Step: 494 Score: 0 Total Score: 159
# Episode: 1 Step: 495 Score: 1 Total Score: 160
# Episode: 1 Step: 496 Score: 0 Total Score: 160
# Episode: 1 Step: 497 Score: 0 Total Score: 160
# Episode: 1 Step: 498 Score: 1 Total Score: 161
# Episode: 1 Step: 499 Score: 1 Total Score: 162
# Episode: 1 Step: 500 Score: 0 Total Score: 162
# Episode: 1 Step: 501 Score: 0 Total Score: 162
# Episode: 1 Step: 502 Score: 1 Total Score: 163
# Episode: 1 Step: 503 Score: 0 Total Score: 163
# Episode: 1 Step: 504 Score: 0 Total Score: 163
# Episode: 1 Step: 505 Score: 0 Total Score: 163
# Episode: 1 Step: 506 Score: 1 Total Score: 164
# Episode: 1 Step: 507 Score: 0 Total Score: 164
# Episode: 1 Step: 508 Score: 0 Total Score: 164
# Episode: 1 Step: 509 Score: 1 Total Score: 165
# Episode: 1 Step: 510 Score: 1 Total Score: 166
# Episode: 1 Step: 511 Score: 1 Total Score: 167
# Episode: 1 Step: 512 Score: 0 Total Score: 167
# Episode: 1 Step: 513 Score: 0 Total Score: 167
# Episode: 1 Step: 514 Score: 1 Total Score: 168
# Episode: 1 Step: 515 Score: 1 Total Score: 169
# Episode: 1 Step: 516 Score: 0 Total Score: 169
# Episode: 1 Step: 517 Score: 0 Total Score: 169
# Episode: 1 Step: 518 Score: 0 Total Score: 169
# Episode: 1 Step: 519 Score: 1 Total Score: 170
# Episode: 1 Step: 520 Score: 0 Total Score: 170
# Episode: 1 Step: 521 Score: 0 Total Score: 170
# Episode: 1 Step: 522 Score: 0 Total Score: 170
# Episode: 1 Step: 523 Score: 1 Total Score: 171
# Episode: 1 Step: 524 Score: 1 Total Score: 172
# Episode: 1 Step: 525 Score: 0 Total Score: 172
# Episode: 1 Step: 526 Score: 1 Total Score: 173
# Episode: 1 Step: 527 Score: 1 Total Score: 174
# Episode: 1 Step: 528 Score: 1 Total Score: 175
# Episode: 1 Step: 529 Score: 1 Total Score: 176
# Episode: 1 Step: 530 Score: 1 Total Score: 177
# Episode: 1 Step: 531 Score: 0 Total Score: 177
# Episode: 1 Step: 532 Score: 1 Total Score: 178
# Episode: 1 Step: 533 Score: 0 Total Score: 178
# Episode: 1 Step: 534 Score: 0 Total Score: 178
# Episode: 1 Step: 535 Score: 0 Total Score: 178
# Episode: 1 Step: 536 Score: 1 Total Score: 179
# Episode: 1 Step: 537 Score: 0 Total Score: 179
# Episode: 1 Step: 538 Score: 1 Total Score: 180
# Episode: 1 Step: 539 Score: 0 Total Score: 180
# Episode: 1 Step: 540 Score: 1 Total Score: 181
# Episode: 1 Step: 541 Score: 0 Total Score: 181
# Episode: 1 Step: 542 Score: 0 Total Score: 181
# Episode: 1 Step: 543 Score: 1 Total Score: 182
# Episode: 1 Step: 544 Score: 1 Total Score: 183
# Episode: 1 Step: 545 Score: 1 Total Score: 184
# Episode: 1 Step: 546 Score: 0 Total Score: 184
# Episode: 1 Step: 547 Score: 0 Total Score: 184
# Episode: 1 Step: 548 Score: 0 Total Score: 184
# Episode: 1 Step: 549 Score: 0 Total Score: 184
# Episode: 1 Step: 550 Score: 1 Total Score: 185
# Episode: 1 Step: 551 Score: 0 Total Score: 185
# Episode: 1 Step: 552 Score: 0 Total Score: 185
# Episode: 1 Step: 553 Score: 0 Total Score: 185
# Episode: 1 Step: 554 Score: 0 Total Score: 185
# Episode: 1 Step: 555 Score: 0 Total Score: 185
# Episode: 1 Step: 556 Score: 0 Total Score: 185
# Episode: 1 Step: 557 Score: 0 Total Score: 185
# Episode: 1 Step: 558 Score: 0 Total Score: 185
# Episode: 1 Step: 559 Score: 0 Total Score: 185
# Episode: 1 Step: 560 Score: 0 Total Score: 185
# Episode: 1 Step: 561 Score: 1 Total Score: 186
# Episode: 1 Step: 562 Score: 0 Total Score: 186
# Episode: 1 Step: 563 Score: 0 Total Score: 186
# Episode: 1 Step: 564 Score: 0 Total Score: 186
# Episode: 1 Step: 565 Score: 0 Total Score: 186
# Episode: 1 Step: 566 Score: 0 Total Score: 186
# Episode: 1 Step: 567 Score: 0 Total Score: 186
# Episode: 1 Step: 568 Score: 0 Total Score: 186
# Episode: 1 Step: 569 Score: 0 Total Score: 186
# Episode: 1 Step: 570 Score: 0 Total Score: 186
# Episode: 1 Step: 571 Score: 0 Total Score: 186
# Episode: 1 Step: 572 Score: 1 Total Score: 187
# Episode: 1 Step: 573 Score: 0 Total Score: 187
# Episode: 1 Step: 574 Score: 0 Total Score: 187
# Episode: 1 Step: 575 Score: 0 Total Score: 187
# Episode: 1 Step: 576 Score: 1 Total Score: 188
# Episode: 1 Step: 577 Score: 0 Total Score: 188
# Episode: 1 Step: 578 Score: 0 Total Score: 188
# Episode: 1 Step: 579 Score: 1 Total Score: 189
# Episode: 1 Step: 580 Score: 0 Total Score: 189
# Episode: 1 Step: 581 Score: 1 Total Score: 190
# Episode: 1 Step: 582 Score: 0 Total Score: 190
# Episode: 1 Step: 583 Score: 0 Total Score: 190
# Episode: 1 Step: 584 Score: 1 Total Score: 191
# Episode: 1 Step: 585 Score: 1 Total Score: 192
# Episode: 1 Step: 586 Score: 1 Total Score: 193
# Episode: 1 Step: 587 Score: 0 Total Score: 193
# Episode: 1 Step: 588 Score: 0 Total Score: 193
# Episode: 1 Step: 589 Score: 0 Total Score: 193
# Episode: 1 Step: 590 Score: 0 Total Score: 193
# Episode: 1 Step: 591 Score: 0 Total Score: 193
# Episode: 1 Step: 592 Score: 1 Total Score: 194
# Episode: 1 Step: 593 Score: 0 Total Score: 194
# Episode: 1 Step: 594 Score: 0 Total Score: 194
# Episode: 1 Step: 595 Score: 1 Total Score: 195
# Episode: 1 Step: 596 Score: 1 Total Score: 196
# Episode: 1 Step: 597 Score: 0 Total Score: 196
# Episode: 1 Step: 598 Score: 1 Total Score: 197
# Episode: 1 Step: 599 Score: 0 Total Score: 197
# Episode: 1 Step: 600 Score: 0 Total Score: 197
# Episode: 1 Step: 601 Score: 0 Total Score: 197
# Episode: 1 Step: 602 Score: 0 Total Score: 197
# Episode: 1 Step: 603 Score: 1 Total Score: 198
# Episode: 1 Step: 604 Score: 0 Total Score: 198
# Episode: 1 Step: 605 Score: 1 Total Score: 199
# Episode: 1 Step: 606 Score: 0 Total Score: 199
# Episode: 1 Step: 607 Score: 1 Total Score: 200
# Episode: 1 Step: 608 Score: 0 Total Score: 200
# Episode: 1 Step: 609 Score: 1 Total Score: 201
# Episode: 1 Step: 610 Score: 0 Total Score: 201
# Episode: 1 Step: 611 Score: 0 Total Score: 201
# Episode: 1 Step: 612 Score: 1 Total Score: 202
# Episode: 1 Step: 613 Score: 0 Total Score: 202
# Episode: 1 Step: 614 Score: 1 Total Score: 203
# Episode: 1 Step: 615 Score: 0 Total Score: 203
# Episode: 1 Step: 616 Score: 0 Total Score: 203
# Episode: 1 Step: 617 Score: 1 Total Score: 204
# Episode: 1 Step: 618 Score: 1 Total Score: 205
# Episode: 1 Step: 619 Score: 0 Total Score: 205
# Episode: 1 Step: 620 Score: 0 Total Score: 205
# Episode: 1 Step: 621 Score: 0 Total Score: 205
# Episode: 1 Step: 622 Score: 1 Total Score: 206
# Episode: 1 Step: 623 Score: 0 Total Score: 206
# Episode: 1 Step: 624 Score: 0 Total Score: 206
# Episode: 1 Step: 625 Score: 0 Total Score: 206
# Episode: 1 Step: 626 Score: 0 Total Score: 206
# Episode: 1 Step: 627 Score: 0 Total Score: 206
# Episode: 1 Step: 628 Score: 0 Total Score: 206
# Episode: 1 Step: 629 Score: 0 Total Score: 206
# Episode: 1 Step: 630 Score: 1 Total Score: 207
# Episode: 1 Step: 631 Score: 0 Total Score: 207
# Episode: 1 Step: 632 Score: 0 Total Score: 207
# Episode: 1 Step: 633 Score: 0 Total Score: 207
# Episode: 1 Step: 634 Score: 1 Total Score: 208
# Episode: 1 Step: 635 Score: 1 Total Score: 209
# Episode: 1 Step: 636 Score: 0 Total Score: 209
# Episode: 1 Step: 637 Score: 1 Total Score: 210
# Episode: 1 Step: 638 Score: 0 Total Score: 210
# Episode: 1 Step: 639 Score: 0 Total Score: 210
# Episode: 1 Step: 640 Score: 0 Total Score: 210
# Episode: 1 Step: 641 Score: 1 Total Score: 211
# Episode: 1 Step: 642 Score: 0 Total Score: 211
# Episode: 1 Step: 643 Score: 0 Total Score: 211
# Episode: 1 Step: 644 Score: 1 Total Score: 212
# Episode: 1 Step: 645 Score: 1 Total Score: 213
# Episode: 1 Step: 646 Score: 0 Total Score: 213
# Episode: 1 Step: 647 Score: 1 Total Score: 214
# Episode: 1 Step: 648 Score: 0 Total Score: 214
# Episode: 1 Step: 649 Score: 1 Total Score: 215
# Episode: 1 Step: 650 Score: 0 Total Score: 215
# Episode: 1 Step: 651 Score: 0 Total Score: 215
# Episode: 1 Step: 652 Score: 0 Total Score: 215
# Episode: 1 Step: 653 Score: 0 Total Score: 215
# Episode: 1 Step: 654 Score: 0 Total Score: 215
# Episode: 1 Step: 655 Score: 1 Total Score: 216
# Episode: 1 Step: 656 Score: 0 Total Score: 216
# Episode: 1 Step: 657 Score: 0 Total Score: 216
# Episode: 1 Step: 658 Score: 0 Total Score: 216
# Episode: 1 Step: 659 Score: 0 Total Score: 216
# Episode: 1 Step: 660 Score: 0 Total Score: 216
# Episode: 1 Step: 661 Score: 0 Total Score: 216
# Episode: 1 Step: 662 Score: 0 Total Score: 216
# Episode: 1 Step: 663 Score: 1 Total Score: 217
# Episode: 1 Step: 664 Score: 0 Total Score: 217
# Episode: 1 Step: 665 Score: 0 Total Score: 217
# Episode: 1 Step: 666 Score: 1 Total Score: 218
# Episode: 1 Step: 667 Score: 0 Total Score: 218
# Episode: 1 Step: 668 Score: 0 Total Score: 218
# Episode: 1 Step: 669 Score: 0 Total Score: 218
# Episode: 1 Step: 670 Score: 0 Total Score: 218
# Episode: 1 Step: 671 Score: 1 Total Score: 219
# Episode: 1 Step: 672 Score: 0 Total Score: 219
# Episode: 1 Step: 673 Score: 1 Total Score: 220
# Episode: 1 Step: 674 Score: 0 Total Score: 220
# Episode: 1 Step: 675 Score: 1 Total Score: 221
# Episode: 1 Step: 676 Score: 1 Total Score: 222
# Episode: 1 Step: 677 Score: 0 Total Score: 222
# Episode: 1 Step: 678 Score: 0 Total Score: 222
# Episode: 1 Step: 679 Score: 0 Total Score: 222
# Episode: 1 Step: 680 Score: 1 Total Score: 223
# Episode: 1 Step: 681 Score: 0 Total Score: 223
# Episode: 1 Step: 682 Score: 1 Total Score: 224
# Episode: 1 Step: 683 Score: 0 Total Score: 224
# Episode: 1 Step: 684 Score: 1 Total Score: 225
# Episode: 1 Step: 685 Score: 0 Total Score: 225
# Episode: 1 Step: 686 Score: 1 Total Score: 226
# Episode: 1 Step: 687 Score: 0 Total Score: 226
# Episode: 1 Step: 688 Score: 0 Total Score: 226
# Episode: 1 Step: 689 Score: 0 Total Score: 226
# Episode: 1 Step: 690 Score: 0 Total Score: 226
# Episode: 1 Step: 691 Score: 1 Total Score: 227
# Episode: 1 Step: 692 Score: 1 Total Score: 228
# Episode: 1 Step: 693 Score: 0 Total Score: 228
# Episode: 1 Step: 694 Score: 0 Total Score: 228
# Episode: 1 Step: 695 Score: 0 Total Score: 228
# Episode: 1 Step: 696 Score: 0 Total Score: 228
# Episode: 1 Step: 697 Score: 1 Total Score: 229
# Episode: 1 Step: 698 Score: 1 Total Score: 230
# Episode: 1 Step: 699 Score: 0 Total Score: 230
# Episode: 1 Step: 700 Score: 1 Total Score: 231
# Episode: 1 Step: 701 Score: 0 Total Score: 231
# Episode: 1 Step: 702 Score: 0 Total Score: 231
# Episode: 1 Step: 703 Score: 1 Total Score: 232
# Episode: 1 Step: 704 Score: 0 Total Score: 232
# Episode: 1 Step: 705 Score: 0 Total Score: 232
# Episode: 1 Step: 706 Score: 0 Total Score: 232
# Episode: 1 Step: 707 Score: 1 Total Score: 233
# Episode: 1 Step: 708 Score: 1 Total Score: 234
# Episode: 1 Step: 709 Score: 0 Total Score: 234
# Episode: 1 Step: 710 Score: 0 Total Score: 234
# Episode: 1 Step: 711 Score: 1 Total Score: 235
# Episode: 1 Step: 712 Score: 0 Total Score: 235
# Episode: 1 Step: 713 Score: 0 Total Score: 235
# Episode: 1 Step: 714 Score: 0 Total Score: 235
# Episode: 1 Step: 715 Score: 0 Total Score: 235
# Episode: 1 Step: 716 Score: 0 Total Score: 235
# Episode: 1 Step: 717 Score: 0 Total Score: 235
# Episode: 1 Step: 718 Score: 1 Total Score: 236
# Episode: 1 Step: 719 Score: 0 Total Score: 236
# Episode: 1 Step: 720 Score: 0 Total Score: 236
# Episode: 1 Step: 721 Score: 1 Total Score: 237
# Episode: 1 Step: 722 Score: 1 Total Score: 238
# Episode: 1 Step: 723 Score: 0 Total Score: 238
# Episode: 1 Step: 724 Score: 1 Total Score: 239
# Episode: 1 Step: 725 Score: 0 Total Score: 239
# Episode: 1 Step: 726 Score: 0 Total Score: 239
# Episode: 1 Step: 727 Score: 0 Total Score: 239
# Episode: 1 Step: 728 Score: 0 Total Score: 239
# Episode: 1 Step: 729 Score: 0 Total Score: 239
# Episode: 1 Step: 730 Score: 1 Total Score: 240
# Episode: 1 Step: 731 Score: 0 Total Score: 240
# Episode: 1 Step: 732 Score: 1 Total Score: 241
# Episode: 1 Step: 733 Score: 1 Total Score: 242
# Episode: 1 Step: 734 Score: 0 Total Score: 242
# Episode: 1 Step: 735 Score: 1 Total Score: 243
# Episode: 1 Step: 736 Score: 0 Total Score: 243
# Episode: 1 Step: 737 Score: 0 Total Score: 243
# Episode: 1 Step: 738 Score: 0 Total Score: 243
# Episode: 1 Step: 739 Score: 0 Total Score: 243
# Episode: 1 Step: 740 Score: 0 Total Score: 243
# Episode: 1 Step: 741 Score: 0 Total Score: 243
# Episode: 1 Step: 742 Score: 0 Total Score: 243
# Episode: 1 Step: 743 Score: 0 Total Score: 243
# Episode: 1 Step: 744 Score: 0 Total Score: 243
# Episode: 1 Step: 745 Score: 0 Total Score: 243
# Episode: 1 Step: 746 Score: 0 Total Score: 243
# Episode: 1 Step: 747 Score: 0 Total Score: 243
# Episode: 1 Step: 748 Score: 0 Total Score: 243
# Episode: 1 Step: 749 Score: 0 Total Score: 243
# Episode: 1 Step: 750 Score: 0 Total Score: 243
# Episode: 1 Step: 751 Score: 0 Total Score: 243
# Episode: 1 Step: 752 Score: 1 Total Score: 244
# Episode: 1 Step: 753 Score: 1 Total Score: 245
# Episode: 1 Step: 754 Score: 0 Total Score: 245
# Episode: 1 Step: 755 Score: 0 Total Score: 245
# Episode: 1 Step: 756 Score: 1 Total Score: 246
# Episode: 1 Step: 757 Score: 0 Total Score: 246
# Episode: 1 Step: 758 Score: 0 Total Score: 246
# Episode: 1 Step: 759 Score: 1 Total Score: 247
# Episode: 1 Step: 760 Score: 1 Total Score: 248
# Episode: 1 Step: 761 Score: 1 Total Score: 249
# Episode: 1 Step: 762 Score: 0 Total Score: 249
# Episode: 1 Step: 763 Score: 1 Total Score: 250
# Episode: 1 Step: 764 Score: 0 Total Score: 250
# Episode: 1 Step: 765 Score: 1 Total Score: 251
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-43cc9a1643c2> in <module>
#     107
#     108 gameEnv = GameEnv()
# --> 109 gameEnv.test()
#
# <ipython-input-5-43cc9a1643c2> in test(self)
#     103                 obs, score, done, _ = self.step(action)
#     104                 print('Episode:', i, 'Step:', self.counts, 'Score:',self.score, 'Total Score:', self.total_scores)
# --> 105                 time.sleep(0.03)
#     106
#     107
#
# KeyboardInterrupt:

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adam

# 뉴럴 네트웍 생성
def build_model(actions):
    model = Sequential()
    
    model.add(Flatten(input_shape=(1,) + env.observation_space.shape))
    model.add(Dense(512,activation='relu'))
    model.add(Dense(512,activation='relu'))
    model.add(Dense(512,activation='relu'))
    
    model.add(Dense(actions,activation='linear'))
    return model


from rl.agents import DQNAgent
from rl.memory import SequentialMemory
from rl.policy import BoltzmannQPolicy, GreedyQPolicy
from rl.policy import EpsGreedyQPolicy
from rl.policy import LinearAnnealedPolicy

def build_agent2(model,actions):
    policy = LinearAnnealedPolicy(EpsGreedyQPolicy(), attr='eps',
                                 value_max = 1., value_min=.1, value_test=.05, nb_steps=50000)
    memory = SequentialMemory(limit=50000, window_length=1)
    dqn = DQNAgent(model=model, memory=memory, policy=policy,
                  nb_actions=actions, nb_steps_warmup=10, target_model_update=1e-2)
    return dqn

env = GameEnv()

actions = env.action_space.n

model = build_model(actions)
print(model.summary())

dqn = build_agent2(model,actions)
dqn.compile(Adam(lr=1e-3),metrics=['mae'])
dqn.fit(env, nb_steps=100000,visualize=False, verbose=0)
# Out:
# Env 생성
# init_ball()
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_9 (Flatten)          (None, 2)                 0
# _________________________________________________________________
# dense_36 (Dense)             (None, 512)               1536
# _________________________________________________________________
# dense_37 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_38 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_39 (Dense)             (None, 3)                 1539
# =================================================================
# Total params: 528,387
# Trainable params: 528,387
# Non-trainable params: 0
# _________________________________________________________________
# None
# init_ball()
# <ipython-input-6-d3506bb724ce>:63: DeprecationWarning: an integer is required (got type numpy.float64).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   painter.drawLine(self.sx, self.sy, self.tx, self.ty)
# <ipython-input-6-d3506bb724ce>:104: DeprecationWarning: an integer is required (got type numpy.float64).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   painter.drawLine(self.shtLine.sx, self.shtLine.sy, self.shtLine.tx, self.shtLine.ty)
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()

# %%
# 학습된 모델 디스크에 저장
dqn.save_weights('dqn_angle_shooting_weights.h5f', overwrite=True)
# Out:
# <ipython-input-6-d3506bb724ce>:63: DeprecationWarning: an integer is required (got type numpy.float64).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   painter.drawLine(self.sx, self.sy, self.tx, self.ty)
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()

# %%
import sys
from PyQt5.QtWidgets import *
from PyQt5.QtGui import *
import numpy as np
from ball import *

# Ball 클래스
class Ball():
    def __init__(self, x, y, w, h, c, speedx, speedy):
        super().__init__()

        self.x = x
        self.y = y
        self.w = w
        self.h = h
        self.c = c
        self.speedx = speedx
        self.speedy = speedy

    def draw(self, painter):
        self.x += self.speedx
        self.y += self.speedy

        painter.setBrush(self.c)
        painter.setPen(self.c)
        painter.drawEllipse(QRectF(self.x, self.y, self.w, self.h))

# Line 클래스
class Line():
    def __init__(self, ix, iy, c, angle):
        # 선의 시작점(흰 공의 중심)
        self.sx = ix + 10
        self.sy = iy + 10
        self.c = c
        self.angle = angle

    def draw(self, painter):
        # 선 방정식 구하기
        if self.angle == 0:
            self.tx = 0
            self.ty = 290
        elif self.angle != 90:
            self.a = np.tan(self.angle / 180 * np.pi)  # 기울기
            self.b = self.sy - self.a * self.sx  # 절편

            if self.a > 0:  # 기울기가 양수일 때
                # 선이 벽과 만나는 점의 좌표값
                self.tx = max(-1 * self.b / self.a, 0)
                self.ty = max(self.b, 0)

            elif self.a < 0:  # 기울기가 음수일 때
                # 선과 벽이 만나는 점의 좌표값
                self.tx = min(-1 * self.b / self.a, 400)
                self.ty = max(0, 400 * self.a + self.b)

        else:  # 각이 90도 -> 기울기 무한대
            self.tx = 210
            self.ty = 0
            self.a = 9999
            self.b = 0

        painter.setPen(self.c)
        painter.drawLine(self.sx, self.sy, self.tx, self.ty)

# Game Class
class MainWindowA(QMainWindow):
    def __init__(self):
        super().__init__()

        self.label = QLabel()

        canvas = QPixmap(400, 300)
        self.label.setPixmap(canvas)
        self.setCentralWidget(self.label)

        self.redBall = Ball(0, 0, 10, 10, Qt.red, 0, 0)
        self.whtBall = Ball(200, 250, 20, 20, Qt.white, 0, 0)
        self.shtLine = Line(200, 280, Qt.cyan, 90)

        self.timecounter = 0
        self.init_ball()
        self.explosion = False

        self.exp_img = QImage('exp.png')
        # self.collide = False
        self.timer = None
        self.exp_pos = QPointF(0.0, 0.0)

        self.firing = False

        self.timer_start()

    def draw(self):
        self.timecounter += 1
        painter = QPainter(self.label.pixmap())
        painter.fillRect(0, 0, 400, 300, QBrush(Qt.black))

        self.shtLine.draw(painter)
        self.redBall.draw(painter)
        self.whtBall.draw(painter)

        if self.firing:
            painter.setPen(Qt.red)  # 빔 발사
            painter.drawLine(self.shtLine.sx, self.shtLine.sy, self.shtLine.tx, self.shtLine.ty)
            self.whtBall.draw(painter)

        if self.timecounter % 90 == 0:
            self.init_ball()

        if self.explosion:
            self.sprite_anim(painter)

        self.label.repaint()

        if self.collide:
            return

        # Collision Detection
        if self.firing:
            # 명중 조건 - 조준선과 빨간볼 중심 사이의 거리가 빨간공 반지름보다 작거나 같을 때
            if np.abs(self.shtLine.a * (self.redBall.x+self.redBall.w/2) -\
                    self.redBall.y+self.redBall.h/2+ self.shtLine.b)/np.sqrt(
                self.shtLine.a**2 + 1) <= self.redBall.w/2:
                #print('명중')
                #print('빨간공 위치(%d, %d), 선 각도 %d, 기울기 %f, 절편 %f' % (self.redBall.x, self.redBall.y,
                #                                                  self.shtLine.angle, self.shtLine.a, self.shtLine.b))
                self.timecounter = 0
                self.firing = False
                self.collide = True
                if not self.explosion:
                    self.explosion = True
                    self.exp_pos.x = self.redBall.x - 20  # 폭발 위치
                    self.exp_pos.y = self.redBall.y - 20
                    self.init_ball()
            else:
                # print('불발')
                # print('빨간공 위치(%d, %d), 선 각도 %d, 기울기 %f, 절편 %f' % (self.redBall.x, self.redBall.y,
                #                                                  self.shtLine.angle, self.shtLine.a, self.shtLine.b))
                self.firing = False

    def init_ball(self):
        self.redBall.x = np.random.uniform(low=0, high=380, size=1)
        self.redBall.y = 0
        self.whtBall.y = 280
        self.whtBall.speedy = 0
        self.collide = False
        print('init_ball()')

    def timer_start(self):
        self.timer = QTimer()
        self.timer.setInterval(30)
        self.timer.timeout.connect(self.draw)
        self.timer.start()

    def timer_stop(self):
        self.timer.stop()

    def keyPressEvent(self, evt):
        if evt.key() == Qt.Key_Space:
            self.fire()
        if evt.key() == Qt.Key_Right:
            self.move_right()
        elif evt.key() == Qt.Key_Left:
            self.move_left()

    def sprite_anim(self, painter):
        s = 62
        target = QRectF(self.exp_pos.x, self.exp_pos.y, 62.0, 62.0)
        source = QRectF(0, 0, 62.0, 62.0)  # 폭발 스프라이트의 첫 프레임만 표시한다
        painter.drawImage(target, self.exp_img, source)

        self.explosion = False

    def move_right(self):
        self.shtLine.angle += 1
        # print(self.shtLine.angle)

    def move_left(self):
        self.shtLine.angle -= 1
        # print(self.shtLine.angle)

    def fire(self):
        self.firing = True

# Environment Class

import gym
from gym import spaces
import numpy as np
import threading
import time
import sys
from PyQt5.QtWidgets import *

# Agent 가 학습할 때 사용하는 환경을 제공하는 클래스
# Agent 는 학습을 위해 이 클래스의 멤버변수인 action_space, observation_sapace 를 사용하고
# step(), reset() 함수를 호출할 것이므로 이들 변수와 함수를 통해서 게임이 시작되어 작동하며
# 종료될 수 있어야 한다.
# 이 게임은 step()함수가 1000번 호출되면 1회의 에피소드가 실행된 것으로 작성하였다

class GameEnv(gym.Env):
    """Custom Environment that follows gym interface"""
    metadata = {'render.modes': ['human']}

    def __init__(self):
        super(GameEnv, self).__init__()

        # Define action and observation space
        # They must be gym.spaces objects
        # Example when using discrete actions:
        #self.action_space = spaces.Discrete(N_DISCRETE_ACTIONS)
        # Example for using image as input:
        #self.observation_space = spaces.Box(low=0, high=380, shape=
        #(HEIGHT, WIDTH, N_CHANNELS), dtype=np.uint8)

        self.action_space = spaces.Discrete(3)
        self.observation_space = spaces.Box(low=0, high=380, shape=(2,), dtype=np.float32)

        self.score = 0
        self.total_scores = 0
        self.done = False
        self.counts = 0

        #게임 클래스에 게임루프(무한루프)가 실행되므로 현재 코드와 동시에 실행하도록 하려면 Thread 가 필요함
        self.game = None
        self.game_thread = threading.Thread(target=self.game_window)
        #self.game_thread.daemon = True   # 여기서는 절대 사용 금지
        self.game_thread.start()

        print('Env 생성')

    # 게임을 쓰레드로 실행하기 위해 함수에 포함
    def game_window(self):
        app = QApplication(sys.argv)
        self.game = MainWindowA()
        self.game.show()
        app.exec_()

    def step(self, action):
        self.score = 0
        if action==0:
            if self.game.shtLine.angle >= 0:
                self.game.move_left()
                if self.game.redBall.x + self.game.redBall.w < self.game.shtLine.tx:
                    self.score = 1
        elif action==1:
            if self.game.shtLine.angle <= 180:
                self.game.move_right()
                if self.game.redBall.x + self.game.redBall.w > self.game.shtLine.tx:
                    self.score = 1
        elif action==2:
            self.game.fire()
            if np.abs(self.game.shtLine.a * (self.game.redBall.x+self.game.redBall.w/2) -\
                    self.game.redBall.y+self.game.redBall.h/2+ self.game.shtLine.b)/np.sqrt(
                self.game.shtLine.a**2 + 1) <= self.game.redBall.w/2:
                self.score = 1
                
        self.counts += 1
        
        if self.counts == 1000:
            self.done = True
            
        self.total_scores += self.score
        obs = [self.game.redBall.x, self.game.shtLine.tx]
        return obs, self.score, self.done, {}

    def render(self, mode='human'):
        pass

    def reset(self):
        self.total_scores = 0
        self.counts = 0
        self.done = False
        self.game.init_ball()
        obs = [self.game.redBall.x, self.game.shtLine.tx]
        return obs

    # Env 작동 테스트
    def test(self):
        while not self.game:
            time.sleep(0.1)
        for i in range(1, 101):  # 100회의 에피소드 테스트
            obs = self.reset()

            while not self.done:
                action = self.action_space.sample()
                obs, score, done, _ = self.step(action)
                print('Episode:', i, 'Step:', self.counts, 'Score:',self.score, 'Total Score:', self.total_scores)
                time.sleep(0.03)

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adam

# 뉴럴 네트웍 생성
def build_model(actions):
    model = Sequential()
    
    model.add(Flatten(input_shape=(1,) + env.observation_space.shape))
    model.add(Dense(512,activation='relu'))
    model.add(Dense(512,activation='relu'))
    model.add(Dense(512,activation='relu'))
    
    model.add(Dense(actions,activation='linear'))
    return model


from rl.agents import DQNAgent
from rl.memory import SequentialMemory
from rl.policy import BoltzmannQPolicy, GreedyQPolicy
from rl.policy import EpsGreedyQPolicy
from rl.policy import LinearAnnealedPolicy

def build_agent2(model,actions):
    policy = LinearAnnealedPolicy(EpsGreedyQPolicy(), attr='eps',
                                 value_max = 1., value_min=.1, value_test=.05, nb_steps=50000)
    memory = SequentialMemory(limit=50000, window_length=1)
    dqn = DQNAgent(model=model, memory=memory, policy=policy,
                  nb_actions=actions, nb_steps_warmup=10, target_model_update=1e-2)
    return dqn

# %%
env = GameEnv()

actions = env.action_space.n

model = build_model(actions)
print(model.summary())

dqn = build_agent2(model,actions)
dqn.compile(Adam(lr=1e-3),metrics=['mae'])
dqn.fit(env, nb_steps=100000,visualize=False, verbose=0)
# Out:
# Env 생성
# init_ball()
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 2)                 0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1536
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 528,387
# Trainable params: 528,387
# Non-trainable params: 0
# _________________________________________________________________
# None
# init_ball()
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_v1.py:2070: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# C:\ProgramData\Anaconda3\lib\site-packages\rl\memory.py:40: UserWarning: Not enough entries to sample without replacement. Consider increasing your warm-up phase to avoid oversampling!
#   warnings.warn('Not enough entries to sample without replacement. Consider increasing your warm-up phase to avoid oversampling!')
# <ipython-input-2-9fbb20707f25>:63: DeprecationWarning: an integer is required (got type numpy.float64).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   painter.drawLine(self.sx, self.sy, self.tx, self.ty)
# <ipython-input-2-9fbb20707f25>:104: DeprecationWarning: an integer is required (got type numpy.float64).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   painter.drawLine(self.shtLine.sx, self.shtLine.sy, self.shtLine.tx, self.shtLine.ty)
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()
# init_ball()

# %%
# 저장된 모델 로드
#env = GameEnv()
actions = env.action_space.n
states = env.observation_space.shape[0]
model = build_model(states)
dqn = build_agent2(model, actions)
dqn.compile(Adam(lr=1e-3), metrics=['mae'])

dqn.load_weights('dqn_angle_shooting_weights.h5f')

scores = dqn.test(env, nb_episodes=1000, visualize=True)
print(np.mean(scores.history['episode_reward']))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-fbb21b34383a> in <module>
#       4 states = env.observation_space.shape[0]
#       5 model = build_model(states)
# ----> 6 dqn = build_agent2(model, actions)
#       7 dqn.compile(Adam(lr=1e-3), metrics=['mae'])
#       8
#
# <ipython-input-1-9fbb20707f25> in build_agent2(model, actions)
#     317                                  value_max = 1., value_min=.1, value_test=.05, nb_steps=50000)
#     318     memory = SequentialMemory(limit=50000, window_length=1)
# --> 319     dqn = DQNAgent(model=model, memory=memory, policy=policy,
#     320                   nb_actions=actions, nb_steps_warmup=10, target_model_update=1e-2)
#     321     return dqn
#
# C:\ProgramData\Anaconda3\lib\site-packages\rl\agents\dqn.py in __init__(self, model, policy, test_policy, enable_double_dqn, enable_dueling_network, dueling_type, *args, **kwargs)
#     106         # Validate (important) input.
#     107         if list(model.output.shape) != list((None, self.nb_actions)):
# --> 108             raise ValueError('Model output "{}" has invalid shape. DQN expects a model that has one dimension for each action, in this case {}.'.format(model.output, self.nb_actions))
#     109
#     110         # Parameters.
#
# ValueError: Model output "Tensor("dense_11/BiasAdd:0", shape=(None, 2), dtype=float32)" has invalid shape. DQN expects a model that has one dimension for each action, in this case 3.
